# %% [markdown]
# # Analysis of the *Inspection* and *Order* Datasets
# ### Question 1: *Is the inspection number in the Inspection Dataset always present in the Inspection Order Dataset ?*

# %% [markdown]
# I first start by loading and printing the datasets:

# %%
import pandas as pd
inspected = pd.read_csv("../data/raw/inspection.csv")
inspected.columns = inspected.columns.str.upper().str.replace(' ', '')
inspected.head()
# Out:
#   ORIGINATINGSERVICEREQUESTNUMBER              INSPECTIONCUSTOMER  \
# 0                           55620  LANDSCAPE COURT APARTMENTS LTD
# 1                          357196            YORK CONDO CORP #255
# 2                          102922                       BMCC REIT
# 3                          357352            YORK CONDO CORP #255
# 4                          516054            YORK CONDO CORP #255
#
#    ELEVATINGDEVICESNUMBER  INSPECTIONNUMBER  \
# 0                    9948           3157237
# 1                   28588           2823870
# 2                   76833           3158421
# 3                   28590           2823948
# 4                   28589           3193568
#
#                              INSPECTIONLOCATION          INSPECTIONTYPE  \
# 0        10 WYCOMBE RD  DOWNSVIEW M3M 2W7 ON CA  ED-Followup Inspection
# 1           75 EMMETT AV  TORONTO M6M 5A7 ON CA  ED-Periodic Inspection
# 2  5099 CREEKBANK RD  MISSISSAUGA L4W 1R3 ON CA  ED-Followup Inspection
# 3           75 EMMETT AV  TORONTO M6M 5A7 ON CA  ED-Periodic Inspection
# 4           75 EMMETT AV  TORONTO M6M 5A7 ON CA  ED-Periodic Inspection
#
#   EARLIEST_INSPECTION_DATE LATEST_INSPECTION_DATE INSPECTIONOUTCOME
# 0                1/10/2011              1/10/2011            Passed
# 1                1/10/2011              1/10/2011         Follow up
# 2                1/10/2011              1/10/2011            Passed
# 3                1/10/2011              1/10/2011         Follow up
# 4                1/10/2011              1/10/2011         Follow up

# %%
order = pd.read_csv("../data/raw/order.csv")
order.columns = order.columns.str.upper().str.replace(' ', '')
order.head()
# Out:
#    ELEVATINGDEVICESNUMBER TSSASTANDARDORDERNUMBER REGULATIONREFERENCE  \
# 0                      10                     NaN                 NaN
# 1                      10                     NaN                 NaN
# 2                      10                     NaN                 NaN
# 3                      10                     NaN                 NaN
# 4                      10                     NaN                 NaN
#
#   CLAUSENUMBER CLAUSETEXT DIRECTIVE  \
# 0          NaN        NaN       NaN
# 1          NaN        NaN       NaN
# 2          NaN        NaN       NaN
# 3          NaN        NaN       NaN
# 4          NaN        NaN       NaN
#
#                     INSPECTIONSADDITIONALINFORMATION  RISKSCORE  \
# 0  Top of Car and Hoistway -other**make the car t...       22.0
# 1  Machine room other:**the 5 year tests on gover...       22.0
# 2  Top of Car and Hoistway -other**make the car t...       22.0
# 3  Top of Car and Hoistway -other**install the co...       22.0
# 4  Machine room other:**post the current license ...       15.0
#
#           INSPECTION_TYPE      DATEOFISSUE STATUSOFINSPECTIONORDER  \
# 0  ED-Followup Inspection   3/5/2012 14:08                RESOLVED
# 1  ED-Followup Inspection   3/5/2012 14:07                RESOLVED
# 2  ED-Followup Inspection  3/16/2012 15:16                RESOLVED
# 3  ED-Followup Inspection  3/16/2012 15:16                RESOLVED
# 4  ED-Followup Inspection   3/5/2012 14:11                RESOLVED
#
#    INSPECTIONNUMBER  DAYSTOCOMPLY COMPLIANCEDATE  \
# 0           3747366           1.0       3/6/2012
# 1           3747366           1.0       3/6/2012
# 2           3763443          24.0       4/9/2012
# 3           3763443          24.0       4/9/2012
# 4           3763443          35.0       4/9/2012
#
#                              CUSTOMERORDEREDTOCOMPLY
# 0  LEGISLATIVE ASSEMBLY OF ONTARIO ATTN:  JOHN ED...
# 1  LEGISLATIVE ASSEMBLY OF ONTARIO ATTN:  JOHN ED...
# 2  LEGISLATIVE ASSEMBLY OF ONTARIO ATTN:  JOHN ED...
# 3  LEGISLATIVE ASSEMBLY OF ONTARIO ATTN:  JOHN ED...
# 4  LEGISLATIVE ASSEMBLY OF ONTARIO ATTN:  JOHN ED...

# %% [markdown]
# I then quickly validate if some INSPECTIONNUMBER are present in the inspection set but not in the order set.

# %%
inspected["INSPECTIONNUMBER"].isin(order["INSPECTIONNUMBER"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 143176     True
# 143177     True
# 143178     True
# 143179     True
# 143180    False
# Name: INSPECTIONNUMBER, Length: 143181, dtype: bool

# %% [markdown]
# I then extract any inspection for which the INSPECTIONNUMBER is not found in the orders

# %%
inspectionsWithoutOrder = inspected[~inspected["INSPECTIONNUMBER"].isin(order["INSPECTIONNUMBER"])]
inspectionsWithoutOrder.head()
# Out:
#   ORIGINATINGSERVICEREQUESTNUMBER              INSPECTIONCUSTOMER  \
# 0                           55620  LANDSCAPE COURT APARTMENTS LTD
# 1                          357196            YORK CONDO CORP #255
# 2                          102922                       BMCC REIT
# 3                          357352            YORK CONDO CORP #255
# 4                          516054            YORK CONDO CORP #255
#
#    ELEVATINGDEVICESNUMBER  INSPECTIONNUMBER  \
# 0                    9948           3157237
# 1                   28588           2823870
# 2                   76833           3158421
# 3                   28590           2823948
# 4                   28589           3193568
#
#                              INSPECTIONLOCATION          INSPECTIONTYPE  \
# 0        10 WYCOMBE RD  DOWNSVIEW M3M 2W7 ON CA  ED-Followup Inspection
# 1           75 EMMETT AV  TORONTO M6M 5A7 ON CA  ED-Periodic Inspection
# 2  5099 CREEKBANK RD  MISSISSAUGA L4W 1R3 ON CA  ED-Followup Inspection
# 3           75 EMMETT AV  TORONTO M6M 5A7 ON CA  ED-Periodic Inspection
# 4           75 EMMETT AV  TORONTO M6M 5A7 ON CA  ED-Periodic Inspection
#
#   EARLIEST_INSPECTION_DATE LATEST_INSPECTION_DATE INSPECTIONOUTCOME
# 0                1/10/2011              1/10/2011            Passed
# 1                1/10/2011              1/10/2011         Follow up
# 2                1/10/2011              1/10/2011            Passed
# 3                1/10/2011              1/10/2011         Follow up
# 4                1/10/2011              1/10/2011         Follow up

# %% [markdown]
# I do one final quick test to make sure the above result makes sense:

# %%
order[order["INSPECTIONNUMBER"] == 3157237]
# Out:
# Empty DataFrame
# Columns: [ELEVATINGDEVICESNUMBER, TSSASTANDARDORDERNUMBER, REGULATIONREFERENCE, CLAUSENUMBER, CLAUSETEXT, DIRECTIVE, INSPECTIONSADDITIONALINFORMATION, RISKSCORE, INSPECTION_TYPE, DATEOFISSUE, STATUSOFINSPECTIONORDER, INSPECTIONNUMBER, DAYSTOCOMPLY, COMPLIANCEDATE, CUSTOMERORDEREDTOCOMPLY]
# Index: []

# %% [markdown]
# ### Conclusion: *We can now confirm there some inspections don't have related orders*
# - - -

# %% [markdown]
# ### Question 2: *Sort both datasets by time*

# %% [markdown]
# Let's start with the inspection dataset:

# %%
inspected["EARLIEST_INSPECTION_DATE"] = pd.to_datetime(inspected["EARLIEST_INSPECTION_DATE"])
inspected.sort_values(by='EARLIEST_INSPECTION_DATE', inplace=True)
inspected
# Out:
#       ORIGINATINGSERVICEREQUESTNUMBER  \
# 19512                          330478
# 19633                          377506
# 19634                          398762
# 19635                          506272
# 19636                          116726
# ...                               ...
# 25490                         1953500
# 25491                         1987718
# 25492                         1996888
# 25421                         1927226
# 25512                         1999490
#
#                                       INSPECTIONCUSTOMER  \
# 19512  METRO TORONTO CONDO CORP #914 C/O MANAGEMENT O...
# 19633                 NORTHUMBERLAND SHOPPING CENTRE INC
# 19634                           BCIMC REALTY CORPORATION
# 19635                               UNIVERSITY OF OTTAWA
# 19636            CARLETON PLACE & DISTRICT MEMORIAL HOSP
# ...                                                  ...
# 25490                  CUMBERLAND DEVELOPMENT (2014) INC
# 25491                   RESIDENCES OF OLD MILL INC (PH2)
# 25492                              IVANHOE CAMBRIDGE INC
# 25421     HASTINGS & PRINCE EDWARD DISTRICT SCHOOL BOARD
# 25512                                 PEEL CONDO CORP 22
#
#        ELEVATINGDEVICESNUMBER  INSPECTIONNUMBER  \
# 19512                   63692           3174774
# 19633                   63774           2868242
# 19634                   64362           3158567
# 19635                   37110           3180242
# 19636                   16899           2289576
# ...                       ...               ...
# 25490                64743877           6376322
# 25491                64676699           6460490
# 25492                64655558           6510817
# 25421                64738742           6369384
# 25512                   21977           6578929
#
#                                       INSPECTIONLOCATION  \
# 19512     3 GREYSTONE WALK DR  SCARBOROUGH M1K 5J4 ON CA
# 19633             1111 ELGIN ST W  COBOURG K9A 5H7 ON CA
# 19634               45 O'CONNOR ST  OTTAWA K1P 1A4 ON CA
# 19635     136 JEAN JACQUES LUSSIER  OTTAWA K1N 6N5 ON CA
# 19636       211 LAKE AVE E  CARLETON PLACE K7C 1J4 ON CA
# ...                                                  ...
# 25490       860 CUMBERLAND AVE  BURLINGTON L7N 3V1 ON CA
# 25491               2 OLD MILL DR  TORONTO M6S 0A2 ON CA
# 25492              100 BAYSHORE DR  OTTAWA K2B 8C1 ON CA
# 25421                 84 DIXON DR  TRENTON K8V 5R1 ON CA
# 25512  2323 CONFEDERATION PKY  MISSISSAUGA L5B 1R6 ON CA
#
#                INSPECTIONTYPE EARLIEST_INSPECTION_DATE LATEST_INSPECTION_DATE  \
# 19512  ED-Followup Inspection               2011-01-04               1/4/2011
# 19633  ED-Periodic Inspection               2011-01-04               1/4/2011
# 19634  ED-Followup Inspection               2011-01-04               1/4/2011
# 19635   ED-Initial Inspection               2011-01-04               1/5/2011
# 19636  ED-Periodic Inspection               2011-01-04               1/4/2011
# ...                       ...                      ...                    ...
# 25490   ED-Initial Inspection               2017-01-09               1/9/2017
# 25491  ED-Periodic Inspection               2017-01-09               1/9/2017
# 25492  ED-Periodic Inspection               2017-01-09               1/9/2017
# 25421   ED-Initial Inspection               2017-01-09               1/9/2017
# 25512  ED-Periodic Inspection               2017-01-09               1/9/2017
#
#          INSPECTIONOUTCOME
# 19512               Passed
# 19633               Passed
# 19634            Follow up
# 19635            Follow up
# 19636            Follow up
# ...                    ...
# 25490               Passed
# 25491         DC Follow up
# 25492             Complete
# 25421  DC Follow up Intial
# 25512            Follow up
#
# [143181 rows x 9 columns]

# %% [markdown]
# And now for the order set:

# %%
order["DATEOFISSUE"] = pd.to_datetime(order["DATEOFISSUE"])
order.sort_values(by='DATEOFISSUE', inplace=True)
order
# Out:
#         ELEVATINGDEVICESNUMBER TSSASTANDARDORDERNUMBER REGULATIONREFERENCE  \
# 154212                   82301                     NaN                 NaN
# 154223                   82302                     NaN                 NaN
# 56456                    28144                     NaN                 NaN
# 86651                    36724                     NaN                 NaN
# 161200                   85114                     NaN                 NaN
# ...                        ...                     ...                 ...
# 36551                    21182                   A0148              ED CAD
# 40838                    21977                   A0154              ED CAD
# 40839                    21977                   A0170              ED CAD
# 40841                    21977                   A0165              ED CAD
# 114408                   64502                  EM0652           OESC 2012
#
#        CLAUSENUMBER   CLAUSETEXT  \
# 154212          NaN          NaN
# 154223          NaN          NaN
# 56456           NaN          NaN
# 86651           NaN          NaN
# 161200          NaN          NaN
# ...             ...          ...
# 36551   8.6.1 (CAD)  8.6.1 (CAD)
# 40838   8.6.1 (CAD)  8.6.1 (CAD)
# 40839   8.6.1 (CAD)  8.6.1 (CAD)
# 40841   8.6.1 (CAD)  8.6.1 (CAD)
# 114408        38-04        38-04
#
#                                                 DIRECTIVE  \
# 154212                                                NaN
# 154223                                                NaN
# 56456                                                 NaN
# 86651                                                 NaN
# 161200                                                NaN
# ...                                                   ...
# 36551   The overdue scheduled maintenance task for doo...
# 40838   The overdue category 1  [annual] periodic task...
# 40839   The overdue category 1  [annual] periodic task...
# 40841   The overdue category 1  [annual] periodic task...
# 114408  Provide a cover for the electrical box to prev...
#
#                          INSPECTIONSADDITIONALINFORMATION  RISKSCORE  \
# 154212  Remove the water/oil from the elevator pit in ...  22.000000
# 154223  Remove the water/oil from the elevator pit in ...  22.000000
# 56456   The car light disconnecting means shall be a f...  23.000000
# 86651   Operation other:**This device has been shutdow...   1.000000
# 161200  General (Regulatory Requirements)- other**Perf...  15.000000
# ...                                                   ...        ...
# 36551                                                 NaN   0.158847
# 40838   Complete all Category 1 tests and sign the MCP...   0.135370
# 40839   Complete all Category 1 tests and sign the MCP...   0.069489
# 40841   Complete all Category 1 tests and sign the MCP...   0.020713
# 114408  A cover is needed for the electrical apparatus...   0.072985
#
#                INSPECTION_TYPE         DATEOFISSUE STATUSOFINSPECTIONORDER  \
# 154212  ED-Followup Inspection 2011-01-02 21:52:00                RESOLVED
# 154223  ED-Followup Inspection 2011-01-02 22:01:00                RESOLVED
# 56456        ED-Sub Inspection 2011-01-04 06:41:00                RESOLVED
# 86651   ED-Followup Inspection 2011-01-04 09:02:00                RESOLVED
# 161200  ED-Periodic Inspection 2011-01-04 09:41:00                RESOLVED
# ...                        ...                 ...                     ...
# 36551   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 40838   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 40839   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 40841   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 114408  ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
#
#         INSPECTIONNUMBER  DAYSTOCOMPLY COMPLIANCEDATE  \
# 154212           3184416          79.0      3/22/2011
# 154223           3184417          79.0      3/22/2011
# 56456            3184496          27.0      1/31/2011
# 86651            3197546           8.0      1/12/2011
# 161200           3184595           0.0       1/4/2011
# ...                  ...           ...            ...
# 36551            6509795          30.0       2/8/2017
# 40838            6578929          90.0       4/9/2017
# 40839            6578929          90.0       4/9/2017
# 40841            6578929          90.0       4/9/2017
# 114408           6512510          30.0       2/8/2017
#
#                                   CUSTOMERORDEREDTOCOMPLY
# 154212  NOORANI HOLDINGS LTD O/A HOLIDAY INN EXPRESS &...
# 154223  NOORANI HOLDINGS LTD O/A HOLIDAY INN EXPRESS &...
# 56456   BLUEBIRD APARTMENT   C/O M SCHIKETANZ REAL EST...
# 86651                         SEPROCK LIMITED PARTNERSHIP
# 161200                                     ASHCROFT HOMES
# ...                                                   ...
# 36551                               TCR 2008 EQUITIES INC
# 40838                                  PEEL CONDO CORP 22
# 40839                                  PEEL CONDO CORP 22
# 40841                                  PEEL CONDO CORP 22
# 114408                     TORONTO MARRIOTT  EATON CENTRE
#
# [162172 rows x 15 columns]

# %% [markdown]
# ### Conclusion: *The two sets are now sorted by date!*
# - - -

# %% [markdown]
# ### Question 3: *For the Inspection Orders dataset : Merge the texts of the “DIRECTIVE” and “Inspections additional information” columns. Add a new column.*

# %%
order
# Out:
#         ELEVATINGDEVICESNUMBER TSSASTANDARDORDERNUMBER REGULATIONREFERENCE  \
# 154212                   82301                     NaN                 NaN
# 154223                   82302                     NaN                 NaN
# 56456                    28144                     NaN                 NaN
# 86651                    36724                     NaN                 NaN
# 161200                   85114                     NaN                 NaN
# ...                        ...                     ...                 ...
# 36551                    21182                   A0148              ED CAD
# 40838                    21977                   A0154              ED CAD
# 40839                    21977                   A0170              ED CAD
# 40841                    21977                   A0165              ED CAD
# 114408                   64502                  EM0652           OESC 2012
#
#        CLAUSENUMBER   CLAUSETEXT  \
# 154212          NaN          NaN
# 154223          NaN          NaN
# 56456           NaN          NaN
# 86651           NaN          NaN
# 161200          NaN          NaN
# ...             ...          ...
# 36551   8.6.1 (CAD)  8.6.1 (CAD)
# 40838   8.6.1 (CAD)  8.6.1 (CAD)
# 40839   8.6.1 (CAD)  8.6.1 (CAD)
# 40841   8.6.1 (CAD)  8.6.1 (CAD)
# 114408        38-04        38-04
#
#                                                 DIRECTIVE  \
# 154212                                                NaN
# 154223                                                NaN
# 56456                                                 NaN
# 86651                                                 NaN
# 161200                                                NaN
# ...                                                   ...
# 36551   The overdue scheduled maintenance task for doo...
# 40838   The overdue category 1  [annual] periodic task...
# 40839   The overdue category 1  [annual] periodic task...
# 40841   The overdue category 1  [annual] periodic task...
# 114408  Provide a cover for the electrical box to prev...
#
#                          INSPECTIONSADDITIONALINFORMATION  RISKSCORE  \
# 154212  Remove the water/oil from the elevator pit in ...  22.000000
# 154223  Remove the water/oil from the elevator pit in ...  22.000000
# 56456   The car light disconnecting means shall be a f...  23.000000
# 86651   Operation other:**This device has been shutdow...   1.000000
# 161200  General (Regulatory Requirements)- other**Perf...  15.000000
# ...                                                   ...        ...
# 36551                                                 NaN   0.158847
# 40838   Complete all Category 1 tests and sign the MCP...   0.135370
# 40839   Complete all Category 1 tests and sign the MCP...   0.069489
# 40841   Complete all Category 1 tests and sign the MCP...   0.020713
# 114408  A cover is needed for the electrical apparatus...   0.072985
#
#                INSPECTION_TYPE         DATEOFISSUE STATUSOFINSPECTIONORDER  \
# 154212  ED-Followup Inspection 2011-01-02 21:52:00                RESOLVED
# 154223  ED-Followup Inspection 2011-01-02 22:01:00                RESOLVED
# 56456        ED-Sub Inspection 2011-01-04 06:41:00                RESOLVED
# 86651   ED-Followup Inspection 2011-01-04 09:02:00                RESOLVED
# 161200  ED-Periodic Inspection 2011-01-04 09:41:00                RESOLVED
# ...                        ...                 ...                     ...
# 36551   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 40838   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 40839   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 40841   ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
# 114408  ED-Periodic Inspection 2017-01-09 00:00:00                    OPEN
#
#         INSPECTIONNUMBER  DAYSTOCOMPLY COMPLIANCEDATE  \
# 154212           3184416          79.0      3/22/2011
# 154223           3184417          79.0      3/22/2011
# 56456            3184496          27.0      1/31/2011
# 86651            3197546           8.0      1/12/2011
# 161200           3184595           0.0       1/4/2011
# ...                  ...           ...            ...
# 36551            6509795          30.0       2/8/2017
# 40838            6578929          90.0       4/9/2017
# 40839            6578929          90.0       4/9/2017
# 40841            6578929          90.0       4/9/2017
# 114408           6512510          30.0       2/8/2017
#
#                                   CUSTOMERORDEREDTOCOMPLY
# 154212  NOORANI HOLDINGS LTD O/A HOLIDAY INN EXPRESS &...
# 154223  NOORANI HOLDINGS LTD O/A HOLIDAY INN EXPRESS &...
# 56456   BLUEBIRD APARTMENT   C/O M SCHIKETANZ REAL EST...
# 86651                         SEPROCK LIMITED PARTNERSHIP
# 161200                                     ASHCROFT HOMES
# ...                                                   ...
# 36551                               TCR 2008 EQUITIES INC
# 40838                                  PEEL CONDO CORP 22
# 40839                                  PEEL CONDO CORP 22
# 40841                                  PEEL CONDO CORP 22
# 114408                     TORONTO MARRIOTT  EATON CENTRE
#
# [162172 rows x 15 columns]

# %% [markdown]
# Let's start by replacing all the NaN values with 'N/A'

# %%
order[["DIRECTIVE", "INSPECTIONSADDITIONALINFORMATION"]] = order[["DIRECTIVE", "INSPECTIONSADDITIONALINFORMATION"]].fillna("N/A")
order.head()
# Out:
#         ELEVATINGDEVICESNUMBER TSSASTANDARDORDERNUMBER REGULATIONREFERENCE  \
# 154212                   82301                     NaN                 NaN
# 154223                   82302                     NaN                 NaN
# 56456                    28144                     NaN                 NaN
# 86651                    36724                     NaN                 NaN
# 161200                   85114                     NaN                 NaN
#
#        CLAUSENUMBER CLAUSETEXT DIRECTIVE  \
# 154212          NaN        NaN       N/A
# 154223          NaN        NaN       N/A
# 56456           NaN        NaN       N/A
# 86651           NaN        NaN       N/A
# 161200          NaN        NaN       N/A
#
#                          INSPECTIONSADDITIONALINFORMATION  RISKSCORE  \
# 154212  Remove the water/oil from the elevator pit in ...       22.0
# 154223  Remove the water/oil from the elevator pit in ...       22.0
# 56456   The car light disconnecting means shall be a f...       23.0
# 86651   Operation other:**This device has been shutdow...        1.0
# 161200  General (Regulatory Requirements)- other**Perf...       15.0
#
#                INSPECTION_TYPE         DATEOFISSUE STATUSOFINSPECTIONORDER  \
# 154212  ED-Followup Inspection 2011-01-02 21:52:00                RESOLVED
# 154223  ED-Followup Inspection 2011-01-02 22:01:00                RESOLVED
# 56456        ED-Sub Inspection 2011-01-04 06:41:00                RESOLVED
# 86651   ED-Followup Inspection 2011-01-04 09:02:00                RESOLVED
# 161200  ED-Periodic Inspection 2011-01-04 09:41:00                RESOLVED
#
#         INSPECTIONNUMBER  DAYSTOCOMPLY COMPLIANCEDATE  \
# 154212           3184416          79.0      3/22/2011
# 154223           3184417          79.0      3/22/2011
# 56456            3184496          27.0      1/31/2011
# 86651            3197546           8.0      1/12/2011
# 161200           3184595           0.0       1/4/2011
#
#                                   CUSTOMERORDEREDTOCOMPLY
# 154212  NOORANI HOLDINGS LTD O/A HOLIDAY INN EXPRESS &...
# 154223  NOORANI HOLDINGS LTD O/A HOLIDAY INN EXPRESS &...
# 56456   BLUEBIRD APARTMENT   C/O M SCHIKETANZ REAL EST...
# 86651                         SEPROCK LIMITED PARTNERSHIP
# 161200                                     ASHCROFT HOMES

# %% [markdown]
# And now combine the 2 columns into a new one name DIRECTIVEWITHINFORMATION:

# %%
order["DIRECTIVEWITHINFORMATION"] = order[["DIRECTIVE", "INSPECTIONSADDITIONALINFORMATION"]].agg(' - '.join,axis=1)
order["DIRECTIVEWITHINFORMATION"]
# Out:
# 154212    N/A - Remove the water/oil from the elevator p...
# 154223    N/A - Remove the water/oil from the elevator p...
# 56456     N/A - The car light disconnecting means shall ...
# 86651     N/A - Operation other:**This device has been s...
# 161200    N/A - General (Regulatory Requirements)- other...
#                                 ...
# 36551     The overdue scheduled maintenance task for doo...
# 40838     The overdue category 1  [annual] periodic task...
# 40839     The overdue category 1  [annual] periodic task...
# 40841     The overdue category 1  [annual] periodic task...
# 114408    Provide a cover for the electrical box to prev...
# Name: DIRECTIVEWITHINFORMATION, Length: 162172, dtype: object

# %% [markdown]
# ### Conclusion: *We now have a new column containing both the directive and Inspections additional information*
# - - -

# %% [markdown]
# ### Question 4: *For the Inspections Orders dataset : Does the “RISK SCORE” have missing values ? What is a solution to handle this situation ? Take your decision based on quantitative information about the data. Justify*

# %%
ordersWithoutRiskScore = order["RISKSCORE"][order["RISKSCORE"].isna()]
ordersWithoutRiskScore
# Out:
# 61867    NaN
# 61866    NaN
# 132063   NaN
# 33626    NaN
# 63281    NaN
#           ..
# 114402   NaN
# 114403   NaN
# 23831    NaN
# 114405   NaN
# 114406   NaN
# Name: RISKSCORE, Length: 41553, dtype: float64

# %% [markdown]
# With the above we see that there are indeed quite a few scores missing.
#
# Give the name of this column, we can assume that low scores are better, so it would not make sense to just replace the NaN with zeros.
#
# To at least fill up some of the missing scores, we can extract the orders that have a score, and try to find orders without risk score that have the same device numbers.

# %%
grouped = order.groupby(["ELEVATINGDEVICESNUMBER", "RISKSCORE"],dropna=True)
dict = dict(grouped.groups.keys())
order["RISKSCORE"] = order["ELEVATINGDEVICESNUMBER"].replace(dict)
ordersWithoutRiskScore = order["RISKSCORE"][order["RISKSCORE"].isna()]
ordersWithoutRiskScore
# Out:
# 154212   NaN
# 86975    NaN
# 86976    NaN
# 86973    NaN
# 86977    NaN
#           ..
# 40842    NaN
# 40840    NaN
# 40838    NaN
# 40839    NaN
# 40841    NaN
# Name: RISKSCORE, Length: 30610, dtype: float64

# %% [markdown]
# We managed to update around 25% of rows with this method, which is already pretty good.
#
# Before taking new actions, I want to know what is the percentage of orders without a score for the whole set:

# %%
len(ordersWithoutRiskScore) * 100 / len(order)
# Out:
# 18.875021582024022

# %% [markdown]
# This means that if I decide to simply remove all the orders that don't have a risk score, nearly 20% of the data would be lost, which to me seems like a lot.
#
# I will create a new set containing only the orders that have a risk score, but also keep the original one, in case we'd need all the data.

# %%
ordersWithoutRiskScore = order["RISKSCORE"][order["RISKSCORE"].isna()]
ordersWithoutRiskScore
ordersWithoutRiskScore.to_csv('../data/processed/ordersWithoutRiskScore.csv')

# %% [markdown]
# ### Conclusion: *We now have 2 sets, one with the original data and a new one containing only the order having a risk score.*
#
# *After rereading everything above, I now wonder if this was relevant to use the orders with a score to update some of those who don't. I'm not sure if we can really assess that a specific elevator will always get the same risk score, or if it rather depends on the type of inspection.*
# - - -

# %% [markdown]
# ### Question 5: *For the Inspection dataset : Clean the Inspection Outcome variable : All categories with less than 500 observations must be grouped in a “Other” category.*

# %%
import numpy as np
threshold = 500
outcomes = inspected["INSPECTIONOUTCOME"].value_counts()
to_be_changed = []
for outcome, count in outcomes.items():
    if count < threshold:
        to_be_changed.append(outcome)
inspected.loc[inspected["INSPECTIONOUTCOME"].isin(to_be_changed), "INSPECTIONOUTCOME"] = "Other"
inspected["INSPECTIONOUTCOME"].value_counts()
# Out:
# Follow up              54605
# Passed                 26064
# DC Follow up           22302
# All Orders Resolved    19555
# Complete                7506
# Shutdown                6110
# Other                   2201
# Follow up Major         1117
# Follow up Sub Major     1002
# Follow Up Initial        877
# Unable to Inspect        689
# Fail Initial             602
# Passed Major             551
# Name: INSPECTIONOUTCOME, dtype: int64

# %% [markdown]
# ### Conclusion: *The INSPECTIONOUTCOME column is now cleaned up.*
# - - -

# %% [markdown]
# ### Question 6: *For the Inspection dataset : Clean the Inspection Type variable*

# %%
import numpy as np
threshold = 250
outcomes = inspected["INSPECTIONTYPE"].value_counts()
to_be_changed = []
for outcome, count in outcomes.items():
    if count < threshold:
        to_be_changed.append(outcome)
inspected.loc[inspected["INSPECTIONTYPE"].isin(to_be_changed), "INSPECTIONTYPE"] = "Other"
inspected["INSPECTIONTYPE"].value_counts()
# Out:
# ED-Followup Inspection            55730
# ED-Periodic Inspection            44373
# ED-Minor A Inspection              8222
# ED-Followup Minor Alt              6659
# ED-Sub Inspection                  5969
# ED-Initial Inspection              5505
# ED-Minor B Inspection              5077
# ED-Sub Inspection Major            2985
# ED-Unscheduled Inspection          2870
# ED-Major Alteration Inspection     2421
# ED-Followup Ownership Change        773
# ED-Sub Failed Initial               704
# ED-Sub  Inspection                  631
# Other                               574
# ED-MCP Follow up                    433
# ED-FU Enforcement Action Insp       255
# Name: INSPECTIONTYPE, dtype: int64

# %% [markdown]
# ### Question 7: *For the Inspection dataset : Create binary/dummy variables for the Inspection Outcome and Inspection Type columns. We must keep the text information in the resulting DataFrame.*

# %%
inspectedWithDummies = pd.get_dummies(inspected, columns=["INSPECTIONTYPE", "INSPECTIONOUTCOME"])
x = inspectedWithDummies.columns[inspectedWithDummies.columns.str.contains("INSPECTIONTYPE")].to_list()
y = inspectedWithDummies.columns[inspectedWithDummies.columns.str.contains("INSPECTIONOUTCOME")].to_list()
x.extend(y)
x.append("ELEVATINGDEVICESNUMBER")
x.append("INSPECTIONNUMBER")
inspectedWithDummies = inspectedWithDummies[x]
inspectedWithDummies = inspectedWithDummies.replace(0, np.nan)
inspectedWithDummies
# Out:
#        INSPECTIONTYPE_ED-FU Enforcement Action Insp  \
# 19512                                           NaN
# 19633                                           NaN
# 19634                                           NaN
# 19635                                           NaN
# 19636                                           NaN
# ...                                             ...
# 25490                                           NaN
# 25491                                           NaN
# 25492                                           NaN
# 25421                                           NaN
# 25512                                           NaN
#
#        INSPECTIONTYPE_ED-Followup Inspection  \
# 19512                                    1.0
# 19633                                    NaN
# 19634                                    1.0
# 19635                                    NaN
# 19636                                    NaN
# ...                                      ...
# 25490                                    NaN
# 25491                                    NaN
# 25492                                    NaN
# 25421                                    NaN
# 25512                                    NaN
#
#        INSPECTIONTYPE_ED-Followup Minor Alt  \
# 19512                                   NaN
# 19633                                   NaN
# 19634                                   NaN
# 19635                                   NaN
# 19636                                   NaN
# ...                                     ...
# 25490                                   NaN
# 25491                                   NaN
# 25492                                   NaN
# 25421                                   NaN
# 25512                                   NaN
#
#        INSPECTIONTYPE_ED-Followup Ownership Change  \
# 19512                                          NaN
# 19633                                          NaN
# 19634                                          NaN
# 19635                                          NaN
# 19636                                          NaN
# ...                                            ...
# 25490                                          NaN
# 25491                                          NaN
# 25492                                          NaN
# 25421                                          NaN
# 25512                                          NaN
#
#        INSPECTIONTYPE_ED-Initial Inspection  INSPECTIONTYPE_ED-MCP Follow up  \
# 19512                                   NaN                              NaN
# 19633                                   NaN                              NaN
# 19634                                   NaN                              NaN
# 19635                                   1.0                              NaN
# 19636                                   NaN                              NaN
# ...                                     ...                              ...
# 25490                                   1.0                              NaN
# 25491                                   NaN                              NaN
# 25492                                   NaN                              NaN
# 25421                                   1.0                              NaN
# 25512                                   NaN                              NaN
#
#        INSPECTIONTYPE_ED-Major Alteration Inspection  \
# 19512                                            NaN
# 19633                                            NaN
# 19634                                            NaN
# 19635                                            NaN
# 19636                                            NaN
# ...                                              ...
# 25490                                            NaN
# 25491                                            NaN
# 25492                                            NaN
# 25421                                            NaN
# 25512                                            NaN
#
#        INSPECTIONTYPE_ED-Minor A Inspection  \
# 19512                                   NaN
# 19633                                   NaN
# 19634                                   NaN
# 19635                                   NaN
# 19636                                   NaN
# ...                                     ...
# 25490                                   NaN
# 25491                                   NaN
# 25492                                   NaN
# 25421                                   NaN
# 25512                                   NaN
#
#        INSPECTIONTYPE_ED-Minor B Inspection  \
# 19512                                   NaN
# 19633                                   NaN
# 19634                                   NaN
# 19635                                   NaN
# 19636                                   NaN
# ...                                     ...
# 25490                                   NaN
# 25491                                   NaN
# 25492                                   NaN
# 25421                                   NaN
# 25512                                   NaN
#
#        INSPECTIONTYPE_ED-Periodic Inspection  ...  \
# 19512                                    NaN  ...
# 19633                                    1.0  ...
# 19634                                    NaN  ...
# 19635                                    NaN  ...
# 19636                                    1.0  ...
# ...                                      ...  ...
# 25490                                    NaN  ...
# 25491                                    1.0  ...
# 25492                                    1.0  ...
# 25421                                    NaN  ...
# 25512                                    1.0  ...
#
#        INSPECTIONOUTCOME_Follow up  INSPECTIONOUTCOME_Follow up Major  \
# 19512                          NaN                                NaN
# 19633                          NaN                                NaN
# 19634                          1.0                                NaN
# 19635                          1.0                                NaN
# 19636                          1.0                                NaN
# ...                            ...                                ...
# 25490                          NaN                                NaN
# 25491                          NaN                                NaN
# 25492                          NaN                                NaN
# 25421                          NaN                                NaN
# 25512                          1.0                                NaN
#
#        INSPECTIONOUTCOME_Follow up Sub Major  INSPECTIONOUTCOME_Other  \
# 19512                                    NaN                      NaN
# 19633                                    NaN                      NaN
# 19634                                    NaN                      NaN
# 19635                                    NaN                      NaN
# 19636                                    NaN                      NaN
# ...                                      ...                      ...
# 25490                                    NaN                      NaN
# 25491                                    NaN                      NaN
# 25492                                    NaN                      NaN
# 25421                                    NaN                      1.0
# 25512                                    NaN                      NaN
#
#        INSPECTIONOUTCOME_Passed  INSPECTIONOUTCOME_Passed Major  \
# 19512                       1.0                             NaN
# 19633                       1.0                             NaN
# 19634                       NaN                             NaN
# 19635                       NaN                             NaN
# 19636                       NaN                             NaN
# ...                         ...                             ...
# 25490                       1.0                             NaN
# 25491                       NaN                             NaN
# 25492                       NaN                             NaN
# 25421                       NaN                             NaN
# 25512                       NaN                             NaN
#
#        INSPECTIONOUTCOME_Shutdown  INSPECTIONOUTCOME_Unable to Inspect  \
# 19512                         NaN                                  NaN
# 19633                         NaN                                  NaN
# 19634                         NaN                                  NaN
# 19635                         NaN                                  NaN
# 19636                         NaN                                  NaN
# ...                           ...                                  ...
# 25490                         NaN                                  NaN
# 25491                         NaN                                  NaN
# 25492                         NaN                                  NaN
# 25421                         NaN                                  NaN
# 25512                         NaN                                  NaN
#
#        ELEVATINGDEVICESNUMBER  INSPECTIONNUMBER
# 19512                   63692           3174774
# 19633                   63774           2868242
# 19634                   64362           3158567
# 19635                   37110           3180242
# 19636                   16899           2289576
# ...                       ...               ...
# 25490                64743877           6376322
# 25491                64676699           6460490
# 25492                64655558           6510817
# 25421                64738742           6369384
# 25512                   21977           6578929
#
# [143181 rows x 31 columns]

# %% [markdown]
# ### Question 8: *Aggregation of the Inspection Dataset*

# %%
inspected.head()
# Out:
#       ORIGINATINGSERVICEREQUESTNUMBER  \
# 19512                          330478
# 19633                          377506
# 19634                          398762
# 19635                          506272
# 19636                          116726
#
#                                       INSPECTIONCUSTOMER  \
# 19512  METRO TORONTO CONDO CORP #914 C/O MANAGEMENT O...
# 19633                 NORTHUMBERLAND SHOPPING CENTRE INC
# 19634                           BCIMC REALTY CORPORATION
# 19635                               UNIVERSITY OF OTTAWA
# 19636            CARLETON PLACE & DISTRICT MEMORIAL HOSP
#
#        ELEVATINGDEVICESNUMBER  INSPECTIONNUMBER  \
# 19512                   63692           3174774
# 19633                   63774           2868242
# 19634                   64362           3158567
# 19635                   37110           3180242
# 19636                   16899           2289576
#
#                                    INSPECTIONLOCATION          INSPECTIONTYPE  \
# 19512  3 GREYSTONE WALK DR  SCARBOROUGH M1K 5J4 ON CA  ED-Followup Inspection
# 19633          1111 ELGIN ST W  COBOURG K9A 5H7 ON CA  ED-Periodic Inspection
# 19634            45 O'CONNOR ST  OTTAWA K1P 1A4 ON CA  ED-Followup Inspection
# 19635  136 JEAN JACQUES LUSSIER  OTTAWA K1N 6N5 ON CA   ED-Initial Inspection
# 19636    211 LAKE AVE E  CARLETON PLACE K7C 1J4 ON CA  ED-Periodic Inspection
#
#       EARLIEST_INSPECTION_DATE LATEST_INSPECTION_DATE INSPECTIONOUTCOME
# 19512               2011-01-04               1/4/2011            Passed
# 19633               2011-01-04               1/4/2011            Passed
# 19634               2011-01-04               1/4/2011         Follow up
# 19635               2011-01-04               1/5/2011         Follow up
# 19636               2011-01-04               1/4/2011         Follow up

# %%
inspection_per_elevator = inspectedWithDummies.groupby("ELEVATINGDEVICESNUMBER").count()
inspection_per_elevator
# Out:
#                         INSPECTIONTYPE_ED-FU Enforcement Action Insp  \
# ELEVATINGDEVICESNUMBER
# 8                                                                  0
# 9                                                                  0
# 10                                                                 0
# 11                                                                 0
# 13                                                                 0
# ...                                                              ...
# 64746694                                                           0
# 64746714                                                           0
# 64747545                                                           0
# 64748555                                                           0
# 64748595                                                           0
#
#                         INSPECTIONTYPE_ED-Followup Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                           3
# 9                                                           3
# 10                                                          4
# 11                                                          4
# 13                                                          5
# ...                                                       ...
# 64746694                                                    0
# 64746714                                                    0
# 64747545                                                    0
# 64748555                                                    0
# 64748595                                                    0
#
#                         INSPECTIONTYPE_ED-Followup Minor Alt  \
# ELEVATINGDEVICESNUMBER
# 8                                                          0
# 9                                                          0
# 10                                                         0
# 11                                                         0
# 13                                                         0
# ...                                                      ...
# 64746694                                                   0
# 64746714                                                   0
# 64747545                                                   0
# 64748555                                                   0
# 64748595                                                   0
#
#                         INSPECTIONTYPE_ED-Followup Ownership Change  \
# ELEVATINGDEVICESNUMBER
# 8                                                                 0
# 9                                                                 0
# 10                                                                0
# 11                                                                0
# 13                                                                0
# ...                                                             ...
# 64746694                                                          0
# 64746714                                                          0
# 64747545                                                          0
# 64748555                                                          0
# 64748595                                                          0
#
#                         INSPECTIONTYPE_ED-Initial Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                          0
# 9                                                          0
# 10                                                         0
# 11                                                         0
# 13                                                         0
# ...                                                      ...
# 64746694                                                   1
# 64746714                                                   1
# 64747545                                                   1
# 64748555                                                   1
# 64748595                                                   1
#
#                         INSPECTIONTYPE_ED-MCP Follow up  \
# ELEVATINGDEVICESNUMBER
# 8                                                     0
# 9                                                     0
# 10                                                    0
# 11                                                    0
# 13                                                    0
# ...                                                 ...
# 64746694                                              0
# 64746714                                              0
# 64747545                                              0
# 64748555                                              0
# 64748595                                              0
#
#                         INSPECTIONTYPE_ED-Major Alteration Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                                   0
# 9                                                                   1
# 10                                                                  1
# 11                                                                  1
# 13                                                                  0
# ...                                                               ...
# 64746694                                                            0
# 64746714                                                            0
# 64747545                                                            0
# 64748555                                                            0
# 64748595                                                            0
#
#                         INSPECTIONTYPE_ED-Minor A Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                          1
# 9                                                          1
# 10                                                         1
# 11                                                         1
# 13                                                         1
# ...                                                      ...
# 64746694                                                   0
# 64746714                                                   0
# 64747545                                                   0
# 64748555                                                   0
# 64748595                                                   0
#
#                         INSPECTIONTYPE_ED-Minor B Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                          0
# 9                                                          0
# 10                                                         0
# 11                                                         0
# 13                                                         0
# ...                                                      ...
# 64746694                                                   0
# 64746714                                                   0
# 64747545                                                   0
# 64748555                                                   0
# 64748595                                                   0
#
#                         INSPECTIONTYPE_ED-Periodic Inspection  ...  \
# ELEVATINGDEVICESNUMBER                                         ...
# 8                                                           2  ...
# 9                                                           2  ...
# 10                                                          2  ...
# 11                                                          3  ...
# 13                                                          2  ...
# ...                                                       ...  ...
# 64746694                                                    0  ...
# 64746714                                                    0  ...
# 64747545                                                    0  ...
# 64748555                                                    0  ...
# 64748595                                                    0  ...
#
#                         INSPECTIONOUTCOME_Follow Up Initial  \
# ELEVATINGDEVICESNUMBER
# 8                                                         0
# 9                                                         0
# 10                                                        0
# 11                                                        0
# 13                                                        0
# ...                                                     ...
# 64746694                                                  1
# 64746714                                                  1
# 64747545                                                  0
# 64748555                                                  0
# 64748595                                                  1
#
#                         INSPECTIONOUTCOME_Follow up  \
# ELEVATINGDEVICESNUMBER
# 8                                                 5
# 9                                                 4
# 10                                                5
# 11                                                5
# 13                                                5
# ...                                             ...
# 64746694                                          0
# 64746714                                          0
# 64747545                                          0
# 64748555                                          0
# 64748595                                          0
#
#                         INSPECTIONOUTCOME_Follow up Major  \
# ELEVATINGDEVICESNUMBER
# 8                                                       0
# 9                                                       1
# 10                                                      1
# 11                                                      0
# 13                                                      0
# ...                                                   ...
# 64746694                                                0
# 64746714                                                0
# 64747545                                                0
# 64748555                                                0
# 64748595                                                0
#
#                         INSPECTIONOUTCOME_Follow up Sub Major  \
# ELEVATINGDEVICESNUMBER
# 8                                                           0
# 9                                                           0
# 10                                                          0
# 11                                                          0
# 13                                                          0
# ...                                                       ...
# 64746694                                                    0
# 64746714                                                    0
# 64747545                                                    0
# 64748555                                                    0
# 64748595                                                    0
#
#                         INSPECTIONOUTCOME_Other  INSPECTIONOUTCOME_Passed  \
# ELEVATINGDEVICESNUMBER
# 8                                             0                         1
# 9                                             0                         1
# 10                                            0                         1
# 11                                            1                         1
# 13                                            0                         1
# ...                                         ...                       ...
# 64746694                                      0                         0
# 64746714                                      0                         0
# 64747545                                      0                         1
# 64748555                                      0                         0
# 64748595                                      0                         0
#
#                         INSPECTIONOUTCOME_Passed Major  \
# ELEVATINGDEVICESNUMBER
# 8                                                    0
# 9                                                    0
# 10                                                   0
# 11                                                   0
# 13                                                   0
# ...                                                ...
# 64746694                                             0
# 64746714                                             0
# 64747545                                             0
# 64748555                                             0
# 64748595                                             0
#
#                         INSPECTIONOUTCOME_Shutdown  \
# ELEVATINGDEVICESNUMBER
# 8                                                0
# 9                                                0
# 10                                               0
# 11                                               1
# 13                                               1
# ...                                            ...
# 64746694                                         0
# 64746714                                         0
# 64747545                                         0
# 64748555                                         0
# 64748595                                         0
#
#                         INSPECTIONOUTCOME_Unable to Inspect  INSPECTIONNUMBER
# ELEVATINGDEVICESNUMBER
# 8                                                         0                 6
# 9                                                         0                 7
# 10                                                        0                 9
# 11                                                        0                10
# 13                                                        0                 8
# ...                                                     ...               ...
# 64746694                                                  0                 1
# 64746714                                                  0                 1
# 64747545                                                  0                 1
# 64748555                                                  0                 1
# 64748595                                                  0                 1
#
# [40954 rows x 30 columns]

# %%
inspected_copy = inspected.copy()
latestInspections = inspected_copy.groupby("ELEVATINGDEVICESNUMBER").first()

inspection_without_latest = inspected_copy[~inspected_copy["INSPECTIONNUMBER"].isin(latestInspections["INSPECTIONNUMBER"])]
dummies_inspection_without_latest = pd.get_dummies(inspection_without_latest, columns=["INSPECTIONTYPE", "INSPECTIONOUTCOME"])
x = dummies_inspection_without_latest.columns[dummies_inspection_without_latest.columns.str.contains("INSPECTIONTYPE")].to_list()
y = dummies_inspection_without_latest.columns[dummies_inspection_without_latest.columns.str.contains("INSPECTIONOUTCOME")].to_list()
x.extend(y)
x.append("ELEVATINGDEVICESNUMBER")
x.append("INSPECTIONNUMBER")
dummies_inspection_without_latest = dummies_inspection_without_latest[x]
dummies_inspection_without_latest = dummies_inspection_without_latest.replace(0, np.nan)
inspection_per_elevator = dummies_inspection_without_latest.groupby("ELEVATINGDEVICESNUMBER").count()
inspection_count_per_elevator = inspection_without_latest.groupby("ELEVATINGDEVICESNUMBER").count().reset_index()
inspection_per_elevator['CURRENT'] = inspection_count_per_elevator['ELEVATINGDEVICESNUMBER'].map(latestInspections['INSPECTIONOUTCOME'])
inspection_per_elevator = inspection_per_elevator.dropna()
inspection_per_elevator
# Out:
#                         INSPECTIONTYPE_ED-FU Enforcement Action Insp  \
# ELEVATINGDEVICESNUMBER
# 8                                                                  0
# 9                                                                  0
# 10                                                                 0
# 11                                                                 0
# 13                                                                 0
# ...                                                              ...
# 33475                                                              0
# 33476                                                              0
# 33477                                                              0
# 33478                                                              0
# 33479                                                              0
#
#                         INSPECTIONTYPE_ED-Followup Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                           3
# 9                                                           3
# 10                                                          4
# 11                                                          4
# 13                                                          5
# ...                                                       ...
# 33475                                                       0
# 33476                                                       0
# 33477                                                       0
# 33478                                                       0
# 33479                                                       0
#
#                         INSPECTIONTYPE_ED-Followup Minor Alt  \
# ELEVATINGDEVICESNUMBER
# 8                                                          0
# 9                                                          0
# 10                                                         0
# 11                                                         0
# 13                                                         0
# ...                                                      ...
# 33475                                                      0
# 33476                                                      0
# 33477                                                      0
# 33478                                                      0
# 33479                                                      0
#
#                         INSPECTIONTYPE_ED-Followup Ownership Change  \
# ELEVATINGDEVICESNUMBER
# 8                                                                 0
# 9                                                                 0
# 10                                                                0
# 11                                                                0
# 13                                                                0
# ...                                                             ...
# 33475                                                             0
# 33476                                                             1
# 33477                                                             1
# 33478                                                             1
# 33479                                                             1
#
#                         INSPECTIONTYPE_ED-Initial Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                          0
# 9                                                          0
# 10                                                         0
# 11                                                         0
# 13                                                         0
# ...                                                      ...
# 33475                                                      0
# 33476                                                      0
# 33477                                                      0
# 33478                                                      0
# 33479                                                      0
#
#                         INSPECTIONTYPE_ED-MCP Follow up  \
# ELEVATINGDEVICESNUMBER
# 8                                                     0
# 9                                                     0
# 10                                                    0
# 11                                                    0
# 13                                                    0
# ...                                                 ...
# 33475                                                 0
# 33476                                                 0
# 33477                                                 0
# 33478                                                 0
# 33479                                                 0
#
#                         INSPECTIONTYPE_ED-Major Alteration Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                                   0
# 9                                                                   1
# 10                                                                  1
# 11                                                                  1
# 13                                                                  0
# ...                                                               ...
# 33475                                                               0
# 33476                                                               0
# 33477                                                               0
# 33478                                                               0
# 33479                                                               0
#
#                         INSPECTIONTYPE_ED-Minor A Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                          1
# 9                                                          1
# 10                                                         1
# 11                                                         1
# 13                                                         1
# ...                                                      ...
# 33475                                                      0
# 33476                                                      1
# 33477                                                      1
# 33478                                                      1
# 33479                                                      1
#
#                         INSPECTIONTYPE_ED-Minor B Inspection  \
# ELEVATINGDEVICESNUMBER
# 8                                                          0
# 9                                                          0
# 10                                                         0
# 11                                                         0
# 13                                                         0
# ...                                                      ...
# 33475                                                      0
# 33476                                                      0
# 33477                                                      0
# 33478                                                      0
# 33479                                                      0
#
#                         INSPECTIONTYPE_ED-Periodic Inspection  ...  \
# ELEVATINGDEVICESNUMBER                                         ...
# 8                                                           1  ...
# 9                                                           1  ...
# 10                                                          1  ...
# 11                                                          2  ...
# 13                                                          1  ...
# ...                                                       ...  ...
# 33475                                                       1  ...
# 33476                                                       0  ...
# 33477                                                       0  ...
# 33478                                                       0  ...
# 33479                                                       0  ...
#
#                         INSPECTIONOUTCOME_Follow up  \
# ELEVATINGDEVICESNUMBER
# 8                                                 4
# 9                                                 3
# 10                                                4
# 11                                                4
# 13                                                4
# ...                                             ...
# 33475                                             0
# 33476                                             0
# 33477                                             0
# 33478                                             0
# 33479                                             0
#
#                         INSPECTIONOUTCOME_Follow up Major  \
# ELEVATINGDEVICESNUMBER
# 8                                                       0
# 9                                                       1
# 10                                                      1
# 11                                                      0
# 13                                                      0
# ...                                                   ...
# 33475                                                   0
# 33476                                                   0
# 33477                                                   0
# 33478                                                   0
# 33479                                                   0
#
#                         INSPECTIONOUTCOME_Follow up Sub Major  \
# ELEVATINGDEVICESNUMBER
# 8                                                           0
# 9                                                           0
# 10                                                          0
# 11                                                          0
# 13                                                          0
# ...                                                       ...
# 33475                                                       0
# 33476                                                       0
# 33477                                                       0
# 33478                                                       0
# 33479                                                       0
#
#                         INSPECTIONOUTCOME_Other  INSPECTIONOUTCOME_Passed  \
# ELEVATINGDEVICESNUMBER
# 8                                             0                         1
# 9                                             0                         1
# 10                                            0                         1
# 11                                            1                         1
# 13                                            0                         1
# ...                                         ...                       ...
# 33475                                         0                         1
# 33476                                         0                         0
# 33477                                         0                         0
# 33478                                         0                         0
# 33479                                         0                         0
#
#                         INSPECTIONOUTCOME_Passed Major  \
# ELEVATINGDEVICESNUMBER
# 8                                                    0
# 9                                                    0
# 10                                                   0
# 11                                                   0
# 13                                                   0
# ...                                                ...
# 33475                                                0
# 33476                                                0
# 33477                                                0
# 33478                                                0
# 33479                                                0
#
#                         INSPECTIONOUTCOME_Shutdown  \
# ELEVATINGDEVICESNUMBER
# 8                                                0
# 9                                                0
# 10                                               0
# 11                                               1
# 13                                               1
# ...                                            ...
# 33475                                            0
# 33476                                            0
# 33477                                            0
# 33478                                            0
# 33479                                            0
#
#                         INSPECTIONOUTCOME_Unable to Inspect  INSPECTIONNUMBER  \
# ELEVATINGDEVICESNUMBER
# 8                                                         0                 5
# 9                                                         0                 6
# 10                                                        0                 8
# 11                                                        0                 9
# 13                                                        0                 7
# ...                                                     ...               ...
# 33475                                                     0                 1
# 33476                                                     0                 2
# 33477                                                     0                 2
# 33478                                                     0                 2
# 33479                                                     0                 2
#
#                              CURRENT
# ELEVATINGDEVICESNUMBER
# 8                             Passed
# 9                             Passed
# 10                            Passed
# 11                         Follow up
# 13                         Follow up
# ...                              ...
# 33475                   Fail Initial
# 33476                   Fail Initial
# 33477                   Fail Initial
# 33478                   Fail Initial
# 33479                   Fail Initial
#
# [13294 rows x 31 columns]

# %%
# inspection_without_latest = inspectedcopy[~inspectedcopy["INSPECTIONNUMBER"].isin(latestInspections["INSPECTIONNUMBER"])]
# inspection_count_per_elevator = inspection_without_latest.groupby("ELEVATINGDEVICESNUMBER").count().reset_index()
# inspection_count_per_elevator['CURRENT'] = inspection_count_per_elevator['ELEVATINGDEVICESNUMBER'].map(latestInspections['INSPECTIONOUTCOME'])
# inspection_count_per_elevator
